# %%
import pandas as pd 
import numpy as np 

from itertools import product 
import matplotlib.pyplot as plt 

from sklearn.datasets import make_classification

# %%
def get_test_data(n_features=40, n_informative=10, n_redundant=10, n_samples=10000):
    X, cont = make_classification(n_samples=n_samples, n_features=n_features,
                                  n_informative=n_informative, n_redundant=n_redundant,
                                  random_state=0, shuffle=False)
    
    time_idx = pd.DatetimeIndex(periods=n_samples, freq=pd.tseries.offsets.BDay(),
                                end=pd.datetime.today())
    X = pd.DataFrame(X, index=time_idx)
    cont = pd.Series(cont, index=time_idx).to_frame('bin')
    # Create name of columns
    columns = ['I_' + str(i) for i in range(n_informative)]
    columns += ['R_' + str(i) for i in range(n_redundant)]
    columns += ['N_' + str(i) for i in range(n_features - len(columns))]
    X.columns = columns
    cont['w'] = 1. / cont.shape[0]
    cont['t1'] = pd.Series(cont.index, index=cont.index)
    return X, cont

# %%
X, cont = get_test_data()
# Out:
# /opt/conda/envs/python372/lib/python3.7/site-packages/ipykernel_launcher.py:6: FutureWarning: Creating a DatetimeIndex by passing range endpoints is deprecated.  Use `pandas.date_range` instead.

# %%
X.head()
# Out:
#                                  I_0       I_1       I_2       I_3       I_4  \
# 1981-02-12 14:04:36.062179  2.843740  0.456554  0.171107 -4.511382  0.278990
# 1981-02-13 14:04:36.062179  3.561541 -1.566097  3.342813 -1.938909  2.075749
# 1981-02-16 14:04:36.062179  7.699248 -3.030124 -0.859302 -0.033351  1.113719
# 1981-02-17 14:04:36.062179 -0.149801 -3.182187  2.695894  1.359997  2.992416
# 1981-02-18 14:04:36.062179 -2.157903  0.046380  0.697217 -1.012036  1.856002
#
#                                  I_5       I_6       I_7       I_8       I_9  \
# 1981-02-12 14:04:36.062179 -3.474726  2.955550  2.698865  1.542440  2.198168
# 1981-02-13 14:04:36.062179 -3.486711  0.494908  0.309615  1.059439 -0.792433
# 1981-02-16 14:04:36.062179 -0.877844  2.344033  4.089113  2.287786  0.611413
# 1981-02-17 14:04:36.062179 -0.417971 -1.214058  1.268313 -3.720913 -2.580578
# 1981-02-18 14:04:36.062179 -2.311465  2.715493  0.444433 -1.921790 -2.472372
#
#                             ...      N_10      N_11      N_12      N_13  \
# 1981-02-12 14:04:36.062179  ... -0.330515 -0.845502 -1.477466  1.217536
# 1981-02-13 14:04:36.062179  ... -0.020384 -0.751467  0.212077  0.285038
# 1981-02-16 14:04:36.062179  ...  0.744056  0.914181  1.586483  0.692802
# 1981-02-17 14:04:36.062179  ... -1.960632 -2.064914  1.258648 -1.031856
# 1981-02-18 14:04:36.062179  ... -0.841121  0.081347 -2.587682 -0.416436
#
#                                 N_14      N_15      N_16      N_17      N_18  \
# 1981-02-12 14:04:36.062179  0.304644  1.557365  0.202843  0.160110  0.933805
# 1981-02-13 14:04:36.062179  0.125461  0.203534 -0.376495 -0.938780 -0.142879
# 1981-02-16 14:04:36.062179 -0.953431  0.679360  0.565153  0.219302 -1.110504
# 1981-02-17 14:04:36.062179  0.645146 -0.063900  0.305844  0.371489  3.218969
# 1981-02-18 14:04:36.062179 -1.077859 -0.428086 -0.183735 -0.434254 -2.124955
#
#                                 N_19
# 1981-02-12 14:04:36.062179 -0.132272
# 1981-02-13 14:04:36.062179  0.533263
# 1981-02-16 14:04:36.062179 -1.086061
# 1981-02-17 14:04:36.062179  0.867178
# 1981-02-18 14:04:36.062179 -0.709056
#
# [5 rows x 40 columns]

# %%
cont.head()
# Out:
#                             bin       w                         t1
# 1981-02-12 14:04:36.062179    0  0.0001 1981-02-12 14:04:36.062179
# 1981-02-13 14:04:36.062179    0  0.0001 1981-02-13 14:04:36.062179
# 1981-02-16 14:04:36.062179    0  0.0001 1981-02-16 14:04:36.062179
# 1981-02-17 14:04:36.062179    0  0.0001 1981-02-17 14:04:36.062179
# 1981-02-18 14:04:36.062179    0  0.0001 1981-02-18 14:04:36.062179

# %%
def get_e_vec(dot, var_thres):
    e_val, e_vec = np.linalg.eigh(dot)
    # Descending order
    idx = e_val.argsort()[::-1]
    e_val = e_val[idx]
    e_vec = e_vec[:, idx]
    # Use only positive ones
    e_val = pd.Series(e_val, index=['PC_' + str(i + 1) for i in range(e_val.shape[0])])
    e_vec = pd.DataFrame(e_vec, index=dot.index, columns=e_val.index)
    e_vec = e_vec.loc[:, e_val > 0]
    e_val = e_val.loc[e_val > 0]
    # Reduce dimension with threashold
    cum_var = e_val.cumsum() / e_val.sum()
    dim = cum_var.values.searchsorted(var_thres)
    e_val = e_val.iloc[:dim+1]
    e_vec = e_vec.iloc[:, :dim+1]
    return e_val, e_vec


def orth_feats(dfX, var_thres=.95):
    dfZ = dfX.sub(dfX.mean(), axis=1).div(dfX.std(), axis=1)
    dot = pd.DataFrame(np.dot(dfZ.T, dfZ), index=dfX.columns, columns=dfX.columns)
    e_val, e_vec = get_e_vec(dot, var_thres)
    dfP = pd.DataFrame(np.dot(dfZ, e_vec), index=dfZ.index, columns=e_vec.columns)
    return dfP

# %%
dfP = orth_feats(X)

# %%
dfP.shape
# Out:
# (10000, 28)

# %%
dfP.columns
# Out:
# Index(['PC_1', 'PC_2', 'PC_3', 'PC_4', 'PC_5', 'PC_6', 'PC_7', 'PC_8', 'PC_9',
#        'PC_10', 'PC_11', 'PC_12', 'PC_13', 'PC_14', 'PC_15', 'PC_16', 'PC_17',
#        'PC_18', 'PC_19', 'PC_20', 'PC_21', 'PC_22', 'PC_23', 'PC_24', 'PC_25',
#        'PC_26', 'PC_27', 'PC_28'],
#       dtype='object')

# %%
